# %%
# Alumno: Santiago Maldonado
# Código: 20201547
# Curso: ASIES

# %%
# Simulación social

# %%
## Objetivos:

# %%
#Objetivo 1: representar agentes en la computadora
#Objetivo 2: programar algo que reaccione

# %%
## Características:

# %%
#Característica 1: Los agentes en la computadora no aprenden, la capacidad de reacción esta limitada.
#Característica 2: Los agentes en la computadora no reflexionan

# %%
# Modelamiento en agentes

# %%
## Estrategias:

# %%
strategies=['Rock','Paper','Scissors']

# %%
## Reglas:

# %%
payoff={('Rock','Paper'):(0,1),
        ('Paper','Rock'):(1,0),
        ('Rock','Scissors'):(1,0),
        ('Scissors','Rock'):(0,1),
        ('Paper','Scissors'):(0,1),
        ('Scissors','Paper'):(1,0),
        ('Rock','Rock'):(0,0),
        ('Paper','Paper'):(0,0),
        ('Scissors','Scissors'):(0,0)}

# %%
# Creando y seteando agentes:

# %%
Players=[{'name':'John','score':0,'strategy':None},
         {'name':'Mary','score':0,'strategy':None}]

# %%
# Proceso de decisión:

# %%
from random import choice

#simplest strategy: choose randomly
choice(strategies);

# %%
#Nota: el punto y coma se utiliza para esconder la respuesta.

# %%
# El momento de la verdad:

# %%
## Agente decide la estrategia

# %%
Players[0]['strategy']=choice(strategies)
Players[1]['strategy']=choice(strategies)

# %%
## Decisión tomada:

# %%
Players[0]['strategy'],Players[1]['strategy']
# Out:
# ('Rock', 'Rock')

# %%
# social result of individual decision
result = payoff[Players[0]['strategy'],Players[1]['strategy']]
result
# Out:
# (0, 0)

# %%
## Beneficios:

# %%
# update agents situation
Players[0]['score']+=result[0]
Players[1]['score']+=result[1]

# %%
# current agent situation
Players
# Out:
# [{'name': 'John', 'score': 0, 'strategy': 'Rock'},
#  {'name': 'Mary', 'score': 0, 'strategy': 'Rock'}]

# %%
# Outcome:

# %%
import pandas as pd 

socialResults=pd.DataFrame((Players[0], Players[1]))
socialResults
# Out:
#    name  score strategy
# 0  John      0     Rock
# 1  Mary      0     Rock

# %%
winnerScore=socialResults.score.max()

#social outcome
socialResults[socialResults.score==winnerScore]
# Out:
#    name  score strategy
# 0  John      0     Rock
# 1  Mary      0     Rock

# %%
# Más jugadores:

# %%
# names of players
names=['Jim','Jane','Peter','Zoe']

# %%
# setting up players
society=[{'name':n,'score':0,'strategy':None} for n in names]

# %%
# each player a dict:
society
# Out:
# [{'name': 'Jim', 'score': 0, 'strategy': None},
#  {'name': 'Jane', 'score': 0, 'strategy': None},
#  {'name': 'Peter', 'score': 0, 'strategy': None},
#  {'name': 'Zoe', 'score': 0, 'strategy': None}]

# %%
import itertools 

# pair is a tuple of dicts
for pair in itertools.combinations(society,2):
    print(pair)
# Out:
# ({'name': 'Jim', 'score': 0, 'strategy': None}, {'name': 'Jane', 'score': 0, 'strategy': None})
# ({'name': 'Jim', 'score': 0, 'strategy': None}, {'name': 'Peter', 'score': 0, 'strategy': None})
# ({'name': 'Jim', 'score': 0, 'strategy': None}, {'name': 'Zoe', 'score': 0, 'strategy': None})
# ({'name': 'Jane', 'score': 0, 'strategy': None}, {'name': 'Peter', 'score': 0, 'strategy': None})
# ({'name': 'Jane', 'score': 0, 'strategy': None}, {'name': 'Zoe', 'score': 0, 'strategy': None})
# ({'name': 'Peter', 'score': 0, 'strategy': None}, {'name': 'Zoe', 'score': 0, 'strategy': None})

# %%
import itertools 

# each dict
for player1,player2 in itertools.combinations(society,2):
    print(player1,player2)
# Out:
# {'name': 'Jim', 'score': 0, 'strategy': None} {'name': 'Jane', 'score': 0, 'strategy': None}
# {'name': 'Jim', 'score': 0, 'strategy': None} {'name': 'Peter', 'score': 0, 'strategy': None}
# {'name': 'Jim', 'score': 0, 'strategy': None} {'name': 'Zoe', 'score': 0, 'strategy': None}
# {'name': 'Jane', 'score': 0, 'strategy': None} {'name': 'Peter', 'score': 0, 'strategy': None}
# {'name': 'Jane', 'score': 0, 'strategy': None} {'name': 'Zoe', 'score': 0, 'strategy': None}
# {'name': 'Peter', 'score': 0, 'strategy': None} {'name': 'Zoe', 'score': 0, 'strategy': None}

# %%
# resetting society
society=[{'name':n,'score':0,'strategy':None} for n in names]

# several rounds
for aRound in range(10000):
    
    # en each round:
    for player1,player2 in itertools.combinations(society,2):
        # each chooses strategy
        player1['strategy']=choice(strategies)
        
        player2['strategy']=choice(strategies)
        
        # result from strategy chosen
        result=payoff[player1['strategy'],player2['strategy']]
            
        # update scores
        player1['score']+=result[0]
        player2['score']+=result[1]

# %%
# final situation
society
# Out:
# [{'name': 'Jim', 'score': 10043, 'strategy': 'Scissors'},
#  {'name': 'Jane', 'score': 9890, 'strategy': 'Scissors'},
#  {'name': 'Peter', 'score': 10007, 'strategy': 'Scissors'},
#  {'name': 'Zoe', 'score': 10089, 'strategy': 'Paper'}]

# %%
# as a data frame
socialResults=pd.DataFrame(society)
socialResults
# Out:
#     name  score  strategy
# 0    Jim  10043  Scissors
# 1   Jane   9890  Scissors
# 2  Peter  10007  Scissors
# 3    Zoe  10089     Paper

# %%
winnerScore=socialResults.score.max()

#social outcome
socialResults[socialResults.score==winnerScore]
# Out:
#   name  score strategy
# 3  Zoe  10089    Paper

# %%
# Ejercicio 1:

# %%
# resetting society
society=[{'name':n,'score':0,'strategy':None} for n in names]

# several rounds
for aRound in range(10000):
    
    print(player1['name'] + " chose " + player1['strategy'] +" - "+player2['name'] + " chose " + player2['strategy'] ) 
    if payoff[player1['strategy'],player2['strategy']] == (1,0): 
        print(player1['name'] + " won") 
    if payoff[player1['strategy'],player2['strategy']] == (0,1): 
        print(player2['name'] + " won") 
    else: 
        print("TIE!")
    
    # en each round:
    for player1,player2 in itertools.combinations(society,2):
        # each chooses strategy
        player1['strategy']=choice(strategies)
        
        player2['strategy']=choice(strategies)
                
        # result from strategy chosen
        result=payoff[player1['strategy'],player2['strategy']]
            
        # update scores
        player1['score']+=result[0]
        player2['score']+=result[1]
# Out:
# Peter chose Scissors - Zoe chose Paper
# Peter won
# TIE!
# Peter chose Paper - Zoe chose Paper
# TIE!
# Peter chose Paper - Zoe chose Rock
# Peter won
# TIE!
# Peter chose Rock - Zoe chose Rock
# TIE!
# Peter chose Scissors - Zoe chose Paper
# Peter won
# TIE!
# Peter chose Rock - Zoe chose Paper
# Zoe won
# Peter chose Rock - Zoe chose Scissors
# Peter won
# TIE!
# Peter chose Paper - Zoe chose Paper
# TIE!
# Peter chose Rock - Zoe chose Paper
# Zoe won
# Peter chose Rock - Zoe chose Scissors
# Peter won
# TIE!
# Peter chose Paper - Zoe chose Scissors
# Zoe won
# Peter chose Paper - Zoe chose Rock
# Peter won
# TIE!
# Peter chose Paper - Zoe chose Scissors
# Zoe won
# Peter chose Paper - Zoe chose Paper
# TIE!
# Peter chose Rock - Zoe chose Rock
# TIE!
# Peter chose Rock - Zoe chose Scissors
# Peter won
# TIE!
# Peter chose Rock - Zoe chose Paper
# Zoe won
# Peter chose Rock - Zoe chose Scissors
# Peter won
# TIE!
# Peter chose Rock - Zoe chose Rock
# TIE!
# ...
